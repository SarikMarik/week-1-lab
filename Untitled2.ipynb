# %% [markdown]
# <a href="https://colab.research.google.com/github/SarikMarik/week-1-lab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
# Problem 1

# %%
scores=[72, 85, 90, 68, 88]
print("scores")
average=sum(scores)/len(scores)
print("Average of score is", average)
print(scores[3])
print(scores[2])
# Out:
# scores
# Average of score is 80.6
# 68
# 90

# %% [markdown]
# PROBLEM 2

# %%
study_hours=[1, 2, 3, 4, 5]
exam_scores=[50, 55, 65, 70, 80]
for i in range(len(study_hours)):
  print("Input:", study_hours[i], "hours->Output:", exam_scores[i], "marks")
# Out:
# Input: 1 hours->Output: 50 marks
# Input: 2 hours->Output: 55 marks
# Input: 3 hours->Output: 65 marks
# Input: 4 hours->Output: 70 marks
# Input: 5 hours->Output: 80 marks
